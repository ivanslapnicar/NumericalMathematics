# %% [markdown]
# # Introduction
#
# __Numerical analysis is the science of computing the solutions of problems that are posed
# mathematically in the field of real or complex numbers.__
#
# Let us just give a couple of examples.
#
# ## Computation of $\pi \approx 3.14159265358979$
#
# $\pi$ is known as the ratio of the circumference of a circle and its diameter.
#
# __Archimedes Method__
#
# Inscribe a regular $n$-gon in a circle of radius $1$. Compute the perimeter of its
# upper half. This is easiest to do if $n=2^k$. Using geometric reasoning,
#
# $$
# p(n) = 2n \sin \: \frac{\pi}{2n}.
# $$
#
# Even though this refers to $\pi$ we can compute this value for $n=1,2,\cdots, $ without
# computing $\pi$ and without punching the $\sin$ button on our calculator. (Computing
# the $\sin$ function requires you to know $\pi$!)
#
# From geometric reasoning, we know that
#
# $$
# \sin \: \frac{\pi}{2} =1, \quad \sin \: \frac{\pi}{4} = \frac{\sqrt{2}}{2}.
# $$
#
# So
#
# $$
# p(1)= 2 \cdot \sin \: \frac{\pi}{2} =2, \quad p(2) = 4 \cdot \sin \: \frac{\pi}{4} = 2\sqrt{2}= 2.828427125
# $$
#
# but what is $p(4) = 8 \cdot \sin \: \displaystyle\frac{\pi}{8}$. Use half angle formulas!
#
# \begin{eqnarray*}
# \sin \: \frac{\theta}{2} = \sqrt{\frac{1-\cos \: \theta }{2}}, \quad \cos \: \theta = \sqrt{1-\sin^2 \: \theta } .
# \end{eqnarray*}
#
# That yields
#
# $$
# \sin \: \frac{\pi}{8} = 0.382683432.
# $$
#
# Thus
#
# $$
# p(4) = 8 \cdot \sin \: \frac{\pi}{8}=3.061467459.
# $$
#
# Continuing this process we get
#
# n | $\sin\displaystyle\frac{\pi}{2n}$ | $p(n)$
# :---|:---|:---
# 1 | 1 | 2
# 2 | $\sqrt{0.5}$ | 2.82842712
# 4 |  0.382683432 | 3.061467459
# 8 | 0.195090322 | 3.121445152
# 16 | 0.09801714 | 3.136548491
# 32 | 0.049067674 | 3.140331157
#
# This method is slow, but "sure".

# %%
pi
# Out:
# π = 3.1415926535897...

# %%
steps=20
s=1.0
c=0.0
for n=1:steps
    s=sqrt((1-c)/2)
    c=sqrt(1-s^2)
    println("2n = ", 2^(n+1), ", approximate value of π = ",2^(n+1)*s)
end
"exact π", Float64(pi)
# Out:
# 2n = 4, approximate value of π = 2.8284271247461903
# 2n = 8, approximate value of π = 3.0614674589207187
# 2n = 16, approximate value of π = 3.121445152258053
# 2n = 32, approximate value of π = 3.1365484905459406
# 2n = 64, approximate value of π = 3.140331156954739
# 2n = 128, approximate value of π = 3.141277250932757
# 2n = 256, approximate value of π = 3.1415138011441455
# 2n = 512, approximate value of π = 3.1415729403678827
# 2n = 1024, approximate value of π = 3.141587725279961
# 2n = 2048, approximate value of π = 3.141591421504635
# 2n = 4096, approximate value of π = 3.141592345611077
# 2n = 8192, approximate value of π = 3.1415925765450043
# 2n = 16384, approximate value of π = 3.1415926334632482
# 2n = 32768, approximate value of π = 3.141592654807589
# 2n = 65536, approximate value of π = 3.1415926453212153
# 2n = 131072, approximate value of π = 3.1415926073757197
# 2n = 262144, approximate value of π = 3.1415929109396727
# 2n = 524288, approximate value of π = 3.141594125195191
# 2n = 1048576, approximate value of π = 3.1415965537048196
# 2n = 2097152, approximate value of π = 3.1415965537048196
# ("exact π", 3.141592653589793)

# %% [markdown]
# __Problem.__ Increase the number of steps and explain what happens.

# %% [markdown]
# Later, we will give a modern enhancement that
# is faster. Letting $h=1/(2n)$ we have that
#
# $$
# p(n) = \frac{\sin \: \pi h}{h} = \pi -a_2 h^2 + a_4 h^4 - \cdots
# $$
#
# where $a_k = \pi^{k+1}/(k+1)!$. Thus this converges to $\pi$ at roughly the rate of
# $O(h^2)$. This is an _approximation problem_. There is no finite algorithm
# to compute $\pi$, since it is a transcendental number (irrational and not the root of
# any polynomial with integer coefficients). However, we can approximate it arbitrarily
# well.

# %% [markdown]
# ## Quadratic equation
#
# The following problem poses completely different issues.
#
# Let us compute roots of $p(x) = ax^2 + bx +c =0$ for constants $a$, $b$ and $c$.
#
# The solution is just
#
# $$
# x_{1,2} = \frac{ -b \pm \sqrt{b^2 - 4ac}}{2a}. \tag{1}
# $$
#
# How do we go about writing a code to compute this.
#
# Take care of special cases.
#
# __Case I.__ $a=0, b \neq 0$.
#
# It is no longer a quadratic, it is linear. Only solution is
#
# $$
# x_1 = -c/b.
# $$
#
# __Case II.__ $a=b=0$
#
# If $c \neq 0$, no solution. If $c=0$, all $x$ are solutions.
#
# The cases you spent time on in high school had to do with the discriminant
# $b^2 - 4ac$.
#
# __Case III.__ $b^2 -4ac < 0$. Two Complex Roots (not real).
#
# $$
# x_{1,2} = -\frac{b}{2a} \pm \mathbf{i} \frac{\sqrt{4ac-b^2}}{2a}, \quad \mathbf{i}^2 = -1.
# $$
#
# __Case IV.__ $b^2 - 4ac =0$. One Double Root (real)
#
# $$
# x_1 = x_2 = -\frac{b}{2a}.
# $$
#
# __Case V.__ $b^2 -4ac > 0$. Two Distinct Real Roots.
# Use Formula (1)?

# %%
a=1
b=2
c=10.0^(-17)
x₁=(-b-sqrt(b*b-4*a*c))/(2*a)
x₂=(-b+sqrt(b*b-4*a*c))/(2*a)

x₁,x₂
# Out:
# (-2.0, 0.0)

# %% [markdown]
# The two real roots are (to about 17 digits)
#
# $$
# x_1 = -2, \quad x_2 = -5 \cdot 10^{-18}.
# $$
#
# The above algorithm gets $x_1$ right, but $x_2 = 0$. The standard double precision floating-point number format, `Float64`, stores about $15$ decimal digits (54 binary digits) and in those 15 digits $\sqrt{b^2 -4ac}-b =0$.
# That is because we are subtracting two close numbers and one of these is approximate, so this difference is "all rounding error". A simple observation gets around this problem.
#
# The "large" root of the quadratic in __Case V__ is
#
# $$
# x_1 = \frac{ -b - \mathrm{sign}(b) \sqrt{b^2 - 4ac}}{2a}
# $$
#
# and the two roots satisfy
#
# $$
# x_1 x_2 = \frac{c}{a}.
# $$
#
# Notice that except inside the square root, we are adding numbers of the same sign!
# After some algebra, we get a formula for the small root
#
# $$
# x_2 = \frac{c}{a x_1} = \frac{-2c}{ b + \mathrm{sign}(b) \sqrt{b^2 - 4ac}}.
# $$
#
# Using this formula we compute both roots to near machine precision.
#
# In this example, we have an exact formula, but in floating point arithmetic the standard quadratic formula
# yields results that are significantly different from what it yields in real arithmetic.

# %%
x₁=(-b-sign(b)*sqrt(b*b-4*a*c))/(2*a)
x₂=-2*c/(b+sign(b)*sqrt(b*b-4*a*c))
x₁,x₂
# Out:
# (-2.0, -4.9999999999999996e-18)

# %% [markdown]
# The following function implements all five cases. Try out the function with different inputs and cover all five cases.

# %%
function quadroots(a,b,c)
    # Function to find the roots of the quadratic equation
    # given coefficients a,b, and c.
    # This function takes no account of scaling. 
    if a==0
        #  Check odd cases when a=0 
        if b==0
            if c==0
                return "all numbers are roots a=b=c=0"
            else
                return "no roots a=b=0, c ne 0"
            end
        else
            x₁=-c/b
            x₂=x₁
            ier="one root a=0"
        end
    else
        Δ = b*b-4*a*c
        if Δ < 0
            # Two complex roots computed with real arithmetic
            ximaginary=sqrt(-Δ)/(2*a)
            xreal=-b/(2*a)
            x₁=xreal+im*ximaginary
            # x₂ is the complex conjugate of x₁, 
            # x₂ = xreal - im*ximaginary
            x₂=conj(x₁)
        else
            if b==0
                # Since Julia handles complex arithmetic without a
                # blink, we can just use the formula in this case.
                x₁=sqrt(-c)/a
                x₂=-x₁
            else
                # Case where there are two real roots.
                x₁=(-b-sign(b)*sqrt(Δ))/(2*a)
                x₂=-2*c/(b+sign(b)*sqrt(Δ))
            end
        end
        ier="roots are good"
    end
    x₁, x₂, ier
end
# Out:
# quadroots (generic function with 1 method)

# %%
quadroots(1,0,7)
# Out:
# (0.0 + 2.6457513110645907im, 0.0 - 2.6457513110645907im, "roots are good")

# %%
quadroots(a,b,c)
# Out:
# (-2.0, -4.9999999999999996e-18, "roots are good")

# %% [markdown]
# ## Julia is fast and open
#
# `Julia` is __fast__ and is the first language to solve the "two language problem", for example using Matlab or Python for development and C, C++ or C# for speed. Every function is compiled after the first call using [JIT compiler](https://en.wikipedia.org/wiki/Just-in-time_compilation), in this case [LLVM](https://en.wikipedia.org/wiki/LLVM).
#
# `Julia` is  __open__ since
# * The complete source code is always accessible on GitHub.
# * MIT license.
# * Macro `@which` makes orientation easy.
# * LLVM and assembler code are easily displayed.

# %%
# Yet another package, follow instructions if not installed.
using Polynomials

# %%
# Contents of a package
varinfo(Polynomials)
# Out:
#   name                       size summary
#   ––––––––––––––––––– ––––––––––– ––––––––––––––––––
#   AbstractPolynomial     40 bytes UnionAll
#   ChebyshevT             40 bytes UnionAll
#   ImmutablePolynomial    80 bytes UnionAll
#   LaurentPolynomial      40 bytes UnionAll
#   Polynomial             40 bytes UnionAll
#   Polynomials         647.540 KiB Module
#   SparsePolynomial       40 bytes UnionAll
#   chop!                   0 bytes typeof(chop!)
#   coeffs                  0 bytes typeof(coeffs)
#   companion               0 bytes typeof(companion)
#   degree                  0 bytes typeof(degree)
#   derivative              0 bytes typeof(derivative)
#   domain                  0 bytes typeof(domain)
#   fit                     0 bytes typeof(fit)
#   fromroots               0 bytes typeof(fromroots)
#   hasnan                  0 bytes typeof(hasnan)
#   integrate               0 bytes typeof(integrate)
#   isintegral              0 bytes typeof(isintegral)
#   ismonic                 0 bytes typeof(ismonic)
#   mapdomain               0 bytes typeof(mapdomain)
#   printpoly               0 bytes typeof(printpoly)
#   roots                   0 bytes typeof(roots)
#   truncate!               0 bytes typeof(truncate!)
#   vander                  0 bytes typeof(vander)
#   variable                0 bytes typeof(variable)

# %%
?Polynomial
# Out:
# search: Polynomial Polynomials LaurentPolynomial AbstractPolynomial
#   Polynomial{T<:Number}(coeffs::AbstractVector{T}, var=:x)
#
#   Construct a polynomial from its coefficients a, lowest order first,
#   optionally in terms of the given variable x. x can be a character, symbol,
#   or string.
#
#   If p = a_n x^n + \ldots + a_2 x^2 + a_1 x + a_0, we construct this through
#   Polynomial([a_0, a_1, ..., a_n]).
#
#   The usual arithmetic operators are overloaded to work with polynomials as
#   well as with combinations of polynomials and scalars. However, operations
#   involving two polynomials of different variables causes an error except
#   those involving a constant polynomial.
#
#   Examples
#   ≡≡≡≡≡≡≡≡≡≡
#
#   DocTestSetup = quote
#       using Polynomials
#   end
#
#   julia> Polynomial([1, 0, 3, 4])
#   Polynomial(1 + 3*x^2 + 4*x^3)
#
#   julia> Polynomial([1, 2, 3], :s)
#   Polynomial(1 + 2*s + 3*s^2)
#
#   julia> one(Polynomial)
#   Polynomial(1.0)

# %%
p=Polynomial([c,b,a])
# Out:
# Polynomial(9.999999999999999e-18 + 2.0*x + 1.0*x^2)

# %%
roots(p)
# Out:
# 2-element Array{Float64,1}:
#  -2.0
#  -4.9999999999999996e-18

# %%
@which roots(p)
# Out:
# roots(p::P; kwargs...) where {T, P<:Polynomials.StandardBasisPolynomial{T}} in Polynomials at C:\Users\Ivan\.julia\packages\Polynomials\r292C\src\polynomials\standard-basis.jl:269

# %% [markdown]
# You can also take a look at the corresponding GitHub file for the most recent version.

# %%
@code_llvm quadroots(1,0,7)
# Out:
# ;  @ In[20]:5 within `quadroots'
# ; Function Attrs: uwtable
# define nonnull %jl_value_t addrspace(10)* @julia_quadroots_18595(i64, i64, i64) #0 {
# top:
#   %3 = alloca %jl_value_t addrspace(10)*, i32 3
#   %gcframe = alloca %jl_value_t addrspace(10)*, i32 4, align 16
#   %4 = bitcast %jl_value_t addrspace(10)** %gcframe to i8*
#   call void @llvm.memset.p0i8.i32(i8* align 16 %4, i8 0, i32 32, i1 false)
#   %5 = call %jl_value_t*** inttoptr (i64 1720670528 to %jl_value_t*** ()*)() #8
# ; ┌ @ promotion.jl:398 within `=='
#    %6 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 0
#    %7 = bitcast %jl_value_t addrspace(10)** %6 to i64*
#    store i64 8, i64* %7
#    %8 = getelementptr %jl_value_t**, %jl_value_t*** %5, i32 0
#    %9 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 1
#    %10 = bitcast %jl_value_t addrspace(10)** %9 to %jl_value_t***
#    %11 = load %jl_value_t**, %jl_value_t*** %8
#    store %jl_value_t** %11, %jl_value_t*** %10
#    %12 = bitcast %jl_value_t*** %8 to %jl_value_t addrspace(10)***
#    store %jl_value_t addrspace(10)** %gcframe, %jl_value_t addrspace(10)*** %12
#    %13 = icmp eq i64 %0, 0
# ; └
#   br i1 %13, label %L3, label %L14
#
# L3:                                               ; preds = %top
# ;  @ In[20]:7 within `quadroots'
# ; ┌ @ promotion.jl:398 within `=='
#    %14 = icmp eq i64 %1, 0
# ; └
#   br i1 %14, label %L5, label %L9
#
# L5:                                               ; preds = %L3
# ;  @ In[20]:8 within `quadroots'
# ; ┌ @ promotion.jl:398 within `=='
#    %15 = icmp eq i64 %2, 0
# ; └
#   %spec.select = select i1 %15, %jl_value_t addrspace(10)* addrspacecast (%jl_value_t* inttoptr (i64 370462192 to %jl_value_t*) to %jl_value_t addrspace(10)*), %jl_value_t addrspace(10)* addrspacecast (%jl_value_t* inttoptr (i64 370462240 to %jl_value_t*) to %jl_value_t addrspace(10)*)
#   %16 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 1
#   %17 = load %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %16
#   %18 = getelementptr %jl_value_t**, %jl_value_t*** %5, i32 0
#   %19 = bitcast %jl_value_t*** %18 to %jl_value_t addrspace(10)**
#   store %jl_value_t addrspace(10)* %17, %jl_value_t addrspace(10)** %19
# ;  @ In[20]:9 within `quadroots'
#   ret %jl_value_t addrspace(10)* %spec.select
#
# L9:                                               ; preds = %L3
# ;  @ In[20]:14 within `quadroots'
# ; ┌ @ int.jl:51 within `-'
#    %20 = sub i64 0, %2
# ; └
# ; ┌ @ int.jl:59 within `/'
# ; │┌ @ float.jl:277 within `float'
# ; ││┌ @ float.jl:262 within `AbstractFloat'
# ; │││┌ @ float.jl:60 within `Float64'
#       %21 = sitofp i64 %20 to double
#       %22 = sitofp i64 %1 to double
# ; │└└└
# ; │ @ int.jl:59 within `/' @ float.jl:407
#    %23 = fdiv double %21, %22
#    %24 = insertelement <2 x double> undef, double %23, i32 0
#    %25 = shufflevector <2 x double> %24, <2 x double> undef, <2 x i32> zeroinitializer
# ; └
# ;  @ In[20]:16 within `quadroots'
#   br label %box_union7
#
# L14:                                              ; preds = %top
# ;  @ In[20]:19 within `quadroots'
# ; ┌ @ int.jl:54 within `*'
#    %26 = mul i64 %1, %1
# ; └
# ; ┌ @ operators.jl:529 within `*' @ int.jl:54
#    %27 = shl i64 %0, 2
#    %28 = mul i64 %27, %2
# ; └
# ; ┌ @ int.jl:52 within `-'
#    %29 = sub i64 %26, %28
# ; └
# ;  @ In[20]:20 within `quadroots'
# ; ┌ @ int.jl:49 within `<'
#    %30 = icmp sgt i64 %29, -1
# ; └
#   br i1 %30, label %L46, label %L20
#
# L20:                                              ; preds = %L14
# ;  @ In[20]:22 within `quadroots'
# ; ┌ @ int.jl:51 within `-'
#    %31 = sub i64 0, %29
# ; └
# ; ┌ @ math.jl:583 within `sqrt'
# ; │┌ @ float.jl:277 within `float'
# ; ││┌ @ float.jl:262 within `AbstractFloat'
# ; │││┌ @ float.jl:60 within `Float64'
#       %32 = sitofp i64 %31 to double
# ; │└└└
# ; │ @ math.jl:583 within `sqrt' @ math.jl:557
# ; │┌ @ float.jl:458 within `<'
#     %33 = icmp sgt i64 %31, -1
# ; │└
#    br i1 %33, label %box_union6, label %L24
#
# L24:                                              ; preds = %L20
#    %34 = call nonnull %jl_value_t addrspace(10)* @julia_throw_complex_domainerror_989(%jl_value_t addrspace(10)* addrspacecast (%jl_value_t* inttoptr (i64 399884432 to %jl_value_t*) to %jl_value_t addrspace(10)*), double %32)
#    call void @llvm.trap()
#    unreachable
#
# L46:                                              ; preds = %L14
# ; └
# ;  @ In[20]:29 within `quadroots'
# ; ┌ @ promotion.jl:398 within `=='
#    %35 = icmp eq i64 %1, 0
# ; └
#   br i1 %35, label %L48, label %L71
#
# L48:                                              ; preds = %L46
# ;  @ In[20]:32 within `quadroots'
# ; ┌ @ int.jl:51 within `-'
#    %36 = sub i64 0, %2
# ; └
# ; ┌ @ math.jl:583 within `sqrt'
# ; │┌ @ float.jl:277 within `float'
# ; ││┌ @ float.jl:262 within `AbstractFloat'
# ; │││┌ @ float.jl:60 within `Float64'
#       %37 = sitofp i64 %36 to double
# ; │└└└
# ; │ @ math.jl:583 within `sqrt' @ math.jl:557
# ; │┌ @ float.jl:458 within `<'
#     %38 = icmp sgt i64 %36, -1
# ; │└
#    br i1 %38, label %L54, label %L52
#
# L52:                                              ; preds = %L48
#    %39 = call nonnull %jl_value_t addrspace(10)* @julia_throw_complex_domainerror_989(%jl_value_t addrspace(10)* addrspacecast (%jl_value_t* inttoptr (i64 399884432 to %jl_value_t*) to %jl_value_t addrspace(10)*), double %37)
#    call void @llvm.trap()
#    unreachable
#
# L54:                                              ; preds = %L48
# ; │ @ math.jl:583 within `sqrt' @ math.jl:558
#    %40 = call double @llvm.sqrt.f64(double %37)
# ; └
# ; ┌ @ promotion.jl:314 within `/'
# ; │┌ @ promotion.jl:282 within `promote'
# ; ││┌ @ promotion.jl:259 within `_promote'
# ; │││┌ @ number.jl:7 within `convert'
# ; ││││┌ @ float.jl:60 within `Float64'
#        %41 = sitofp i64 %0 to double
# ; │└└└└
# ; │ @ promotion.jl:314 within `/' @ float.jl:407
#    %42 = fdiv double %40, %41
# ; └
# ;  @ In[20]:33 within `quadroots'
# ; ┌ @ float.jl:393 within `-'
#    %43 = fsub double -0.000000e+00, %42
#    %44 = insertelement <2 x double> undef, double %42, i32 0
#    %45 = insertelement <2 x double> %44, double %43, i32 1
# ; └
#   br label %box_union7
#
# L71:                                              ; preds = %L46
# ;  @ In[20]:36 within `quadroots'
# ; ┌ @ number.jl:118 within `sign'
# ; │┌ @ operators.jl:294 within `>'
# ; ││┌ @ int.jl:49 within `<'
#      %46 = icmp slt i64 %1, 1
# ; │└└
#    %47 = select i1 %46, i64 %1, i64 1
# ; └
# ; ┌ @ math.jl:583 within `sqrt'
# ; │┌ @ float.jl:277 within `float'
# ; ││┌ @ float.jl:262 within `AbstractFloat'
# ; │││┌ @ float.jl:60 within `Float64'
#       %48 = sitofp i64 %29 to double
# ; └└└└
# ;  @ In[20]:37 within `quadroots'
# ; ┌ @ number.jl:118 within `sign'
#    %49 = icmp sgt i64 %47, -1
#    %50 = select i1 %49, i64 %47, i64 -1
# ; └
# ; ┌ @ int.jl:54 within `*'
#    %51 = mul i64 %2, -2
# ; └
# ;  @ In[20]:36 within `quadroots'
# ; ┌ @ int.jl:51 within `-'
#    %52 = sub i64 0, %1
# ; └
# ; ┌ @ promotion.jl:313 within `-'
# ; │┌ @ promotion.jl:282 within `promote'
# ; ││┌ @ promotion.jl:259 within `_promote'
# ; │││┌ @ number.jl:7 within `convert'
# ; ││││┌ @ float.jl:60 within `Float64'
#        %53 = sitofp i64 %52 to double
# ; └└└└└
# ; ┌ @ math.jl:583 within `sqrt' @ math.jl:558
#    %54 = call double @llvm.sqrt.f64(double %48)
# ; └
# ; ┌ @ promotion.jl:312 within `*'
# ; │┌ @ promotion.jl:282 within `promote'
# ; ││┌ @ promotion.jl:259 within `_promote'
# ; │││┌ @ number.jl:7 within `convert'
# ; ││││┌ @ float.jl:60 within `Float64'
#        %55 = sitofp i64 %50 to double
# ; │└└└└
# ; │ @ promotion.jl:312 within `*' @ float.jl:405
#    %56 = fmul double %54, %55
# ; └
# ; ┌ @ promotion.jl:313 within `-' @ float.jl:403
#    %57 = fsub double %53, %56
# ; └
# ; ┌ @ int.jl:54 within `*'
#    %58 = shl i64 %0, 1
# ; └
# ; ┌ @ promotion.jl:314 within `/'
# ; │┌ @ promotion.jl:282 within `promote'
# ; ││┌ @ promotion.jl:259 within `_promote'
# ; │││┌ @ number.jl:7 within `convert'
# ; ││││┌ @ float.jl:60 within `Float64'
#        %59 = sitofp i64 %58 to double
# ; └└└└└
# ;  @ In[20]:37 within `quadroots'
# ; ┌ @ promotion.jl:311 within `+'
# ; │┌ @ promotion.jl:282 within `promote'
# ; ││┌ @ promotion.jl:259 within `_promote'
# ; │││┌ @ number.jl:7 within `convert'
# ; ││││┌ @ float.jl:60 within `Float64'
#        %60 = sitofp i64 %1 to double
# ; │└└└└
# ; │ @ promotion.jl:311 within `+' @ float.jl:401
#    %61 = fadd double %56, %60
# ; └
# ; ┌ @ promotion.jl:314 within `/'
# ; │┌ @ promotion.jl:282 within `promote'
# ; ││┌ @ promotion.jl:259 within `_promote'
# ; │││┌ @ number.jl:7 within `convert'
# ; ││││┌ @ float.jl:60 within `Float64'
#        %62 = sitofp i64 %51 to double
# ; └└└└└
# ;  @ In[20]:36 within `quadroots'
# ; ┌ @ promotion.jl:314 within `/' @ float.jl:407
#    %63 = insertelement <2 x double> undef, double %57, i32 0
#    %64 = insertelement <2 x double> %63, double %62, i32 1
#    %65 = insertelement <2 x double> undef, double %59, i32 0
#    %66 = insertelement <2 x double> %65, double %61, i32 1
#    %67 = fdiv <2 x double> %64, %66
# ; └
# ;  @ In[20]:37 within `quadroots'
# ; ┌ @ promotion.jl:314 within `/' @ float.jl:407
#    br label %box_union7
#
# post_box_union5:                                  ; preds = %box_union7, %box_union6
#    %68 = phi %jl_value_t addrspace(10)* [ %93, %box_union6 ], [ %108, %box_union7 ]
#    %value_phi91100 = phi %jl_value_t addrspace(10)* [ addrspacecast (%jl_value_t* inttoptr (i64 365524560 to %jl_value_t*) to %jl_value_t addrspace(10)*), %box_union6 ], [ %value_phi90, %box_union7 ]
# ; └
# ;  @ In[20]:42 within `quadroots'
#   %69 = phi %jl_value_t addrspace(10)* [ %100, %box_union6 ], [ %114, %box_union7 ]
#   %70 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 3
#   store %jl_value_t addrspace(10)* %68, %jl_value_t addrspace(10)** %70
#   %71 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 2
#   store %jl_value_t addrspace(10)* %69, %jl_value_t addrspace(10)** %71
#   %72 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %3, i32 0
#   store %jl_value_t addrspace(10)* %68, %jl_value_t addrspace(10)** %72
#   %73 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %3, i32 1
#   store %jl_value_t addrspace(10)* %69, %jl_value_t addrspace(10)** %73
#   %74 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %3, i32 2
#   store %jl_value_t addrspace(10)* %value_phi91100, %jl_value_t addrspace(10)** %74
#   %75 = call nonnull %jl_value_t addrspace(10)* @jl_f_tuple(%jl_value_t addrspace(10)* addrspacecast (%jl_value_t* null to %jl_value_t addrspace(10)*), %jl_value_t addrspace(10)** %3, i32 3)
#   %76 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 1
#   %77 = load %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %76
#   %78 = getelementptr %jl_value_t**, %jl_value_t*** %5, i32 0
#   %79 = bitcast %jl_value_t*** %78 to %jl_value_t addrspace(10)**
#   store %jl_value_t addrspace(10)* %77, %jl_value_t addrspace(10)** %79
#   ret %jl_value_t addrspace(10)* %75
#
# box_union6:                                       ; preds = %L20
# ;  @ In[20]:22 within `quadroots'
# ; ┌ @ math.jl:583 within `sqrt' @ math.jl:558
#    %80 = call double @llvm.sqrt.f64(double %32)
# ; └
# ; ┌ @ int.jl:54 within `*'
#    %81 = shl i64 %0, 1
# ; └
# ; ┌ @ promotion.jl:314 within `/'
# ; │┌ @ promotion.jl:282 within `promote'
# ; ││┌ @ promotion.jl:259 within `_promote'
# ; │││┌ @ number.jl:7 within `convert'
# ; ││││┌ @ float.jl:60 within `Float64'
#        %82 = sitofp i64 %81 to double
# ; │└└└└
# ; │ @ promotion.jl:314 within `/' @ float.jl:407
#    %83 = fdiv double %80, %82
# ; └
# ;  @ In[20]:23 within `quadroots'
# ; ┌ @ int.jl:51 within `-'
#    %84 = sub i64 0, %1
# ; └
# ; ┌ @ int.jl:59 within `/'
# ; │┌ @ float.jl:277 within `float'
# ; ││┌ @ float.jl:262 within `AbstractFloat'
# ; │││┌ @ float.jl:60 within `Float64'
#       %85 = sitofp i64 %84 to double
# ; │└└└
# ; │ @ int.jl:59 within `/' @ float.jl:407
#    %86 = fdiv double %85, %82
# ; └
# ;  @ In[20]:24 within `quadroots'
# ; ┌ @ complex.jl:309 within `*' @ bool.jl:110
# ; │┌ @ floatfuncs.jl:5 within `copysign'
#     %87 = bitcast double %83 to i64
#     %88 = and i64 %87, -9223372036854775808
# ; │└
#    %89 = bitcast i64 %88 to double
# ; └
# ; ┌ @ complex.jl:312 within `+' @ float.jl:401
#    %90 = fadd double %86, %89
# ; └
# ;  @ In[20]:27 within `quadroots'
# ; ┌ @ complex.jl:263 within `conj'
# ; │┌ @ float.jl:393 within `-'
#     %91 = fsub double -0.000000e+00, %83
# ; └└
# ;  @ In[20]:42 within `quadroots'
#   %92 = bitcast %jl_value_t*** %5 to i8*
#   %93 = call noalias nonnull %jl_value_t addrspace(10)* @jl_gc_pool_alloc(i8* %92, i32 1424, i32 32) #3
#   %94 = bitcast %jl_value_t addrspace(10)* %93 to %jl_value_t addrspace(10)* addrspace(10)*
#   %95 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)* addrspace(10)* %94, i64 -1
#   store %jl_value_t addrspace(10)* addrspacecast (%jl_value_t* inttoptr (i64 169188448 to %jl_value_t*) to %jl_value_t addrspace(10)*), %jl_value_t addrspace(10)* addrspace(10)* %95
#   %96 = bitcast %jl_value_t addrspace(10)* %93 to i8 addrspace(10)*
#   %97 = bitcast %jl_value_t addrspace(10)* %93 to double addrspace(10)*
#   store double %90, double addrspace(10)* %97, align 8
#   %.sroa.376.0..sroa_idx = getelementptr inbounds i8, i8 addrspace(10)* %96, i64 8
#   %98 = bitcast i8 addrspace(10)* %.sroa.376.0..sroa_idx to double addrspace(10)*
#   store double %83, double addrspace(10)* %98, align 8
#   %99 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 2
#   store %jl_value_t addrspace(10)* %93, %jl_value_t addrspace(10)** %99
#   %100 = call noalias nonnull %jl_value_t addrspace(10)* @jl_gc_pool_alloc(i8* %92, i32 1424, i32 32) #3
#   %101 = bitcast %jl_value_t addrspace(10)* %100 to %jl_value_t addrspace(10)* addrspace(10)*
#   %102 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)* addrspace(10)* %101, i64 -1
#   store %jl_value_t addrspace(10)* addrspacecast (%jl_value_t* inttoptr (i64 169188448 to %jl_value_t*) to %jl_value_t addrspace(10)*), %jl_value_t addrspace(10)* addrspace(10)* %102
#   %103 = bitcast %jl_value_t addrspace(10)* %100 to i8 addrspace(10)*
#   %104 = bitcast %jl_value_t addrspace(10)* %100 to double addrspace(10)*
#   store double %90, double addrspace(10)* %104, align 8
#   %.sroa.374.0..sroa_idx = getelementptr inbounds i8, i8 addrspace(10)* %103, i64 8
#   %105 = bitcast i8 addrspace(10)* %.sroa.374.0..sroa_idx to double addrspace(10)*
#   store double %91, double addrspace(10)* %105, align 8
#   br label %post_box_union5
#
# box_union7:                                       ; preds = %L71, %L54, %L9
#   %value_phi90 = phi %jl_value_t addrspace(10)* [ addrspacecast (%jl_value_t* inttoptr (i64 365522416 to %jl_value_t*) to %jl_value_t addrspace(10)*), %L9 ], [ addrspacecast (%jl_value_t* inttoptr (i64 365524560 to %jl_value_t*) to %jl_value_t addrspace(10)*), %L54 ], [ addrspacecast (%jl_value_t* inttoptr (i64 365524560 to %jl_value_t*) to %jl_value_t addrspace(10)*), %L71 ]
#   %106 = phi <2 x double> [ %25, %L9 ], [ %45, %L54 ], [ %67, %L71 ]
#   %107 = bitcast %jl_value_t*** %5 to i8*
#   %108 = call noalias nonnull %jl_value_t addrspace(10)* @jl_gc_pool_alloc(i8* %107, i32 1400, i32 16) #3
#   %109 = bitcast %jl_value_t addrspace(10)* %108 to %jl_value_t addrspace(10)* addrspace(10)*
#   %110 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)* addrspace(10)* %109, i64 -1
#   store %jl_value_t addrspace(10)* addrspacecast (%jl_value_t* inttoptr (i64 169059392 to %jl_value_t*) to %jl_value_t addrspace(10)*), %jl_value_t addrspace(10)* addrspace(10)* %110
#   %111 = bitcast %jl_value_t addrspace(10)* %108 to double addrspace(10)*
#   %112 = extractelement <2 x double> %106, i32 0
#   store double %112, double addrspace(10)* %111, align 8
#   %113 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)** %gcframe, i32 2
#   store %jl_value_t addrspace(10)* %108, %jl_value_t addrspace(10)** %113
#   %114 = call noalias nonnull %jl_value_t addrspace(10)* @jl_gc_pool_alloc(i8* %107, i32 1400, i32 16) #3
#   %115 = bitcast %jl_value_t addrspace(10)* %114 to %jl_value_t addrspace(10)* addrspace(10)*
#   %116 = getelementptr %jl_value_t addrspace(10)*, %jl_value_t addrspace(10)* addrspace(10)* %115, i64 -1
#   store %jl_value_t addrspace(10)* addrspacecast (%jl_value_t* inttoptr (i64 169059392 to %jl_value_t*) to %jl_value_t addrspace(10)*), %jl_value_t addrspace(10)* addrspace(10)* %116
#   %117 = bitcast %jl_value_t addrspace(10)* %114 to double addrspace(10)*
#   %118 = extractelement <2 x double> %106, i32 1
#   store double %118, double addrspace(10)* %117, align 8
#   br label %post_box_union5
# }

# %%
@code_native quadroots(1,0,7)
# Out:
# 	.text
# ; ┌ @ In[20]:5 within `quadroots'
# 	pushq	%rbp
# 	movq	%rsp, %rbp
# 	pushq	%r14
# 	pushq	%rsi
# 	pushq	%rdi
# 	pushq	%rbx
# 	andq	$-32, %rsp
# 	subq	$160, %rsp
# 	vmovapd	%xmm8, -48(%rbp)
# 	vmovapd	%xmm7, -64(%rbp)
# 	vmovaps	%xmm6, -80(%rbp)
# 	movq	%r8, %rbx
# 	movq	%rdx, %rsi
# 	movq	%rcx, %rdi
# 	vxorpd	%xmm0, %xmm0, %xmm0
# 	vmovapd	%ymm0, 32(%rsp)
# 	movl	$jl_get_ptls_states, %eax
# 	vzeroupper
# 	callq	*%rax
# 	movq	%rax, %r14
# ; │┌ @ promotion.jl:398 within `=='
# 	movq	$8, 32(%rsp)
# 	movq	(%r14), %rax
# 	movq	%rax, 40(%rsp)
# 	leaq	32(%rsp), %rax
# 	movq	%rax, (%r14)
# 	testq	%rdi, %rdi
# ; │└
# 	je	L245
# ; │ @ In[20]:19 within `quadroots'
# ; │┌ @ int.jl:54 within `*'
# 	movq	%rsi, %rax
# 	imulq	%rax, %rax
# ; │└
# ; │┌ @ operators.jl:529 within `*' @ int.jl:54
# 	movq	%rdi, %rcx
# 	imulq	%rbx, %rcx
# 	shlq	$2, %rcx
# ; │└
# ; │ @ In[20]:20 within `quadroots'
# ; │┌ @ int.jl:49 within `<'
# 	subq	%rcx, %rax
# ; │└
# 	js	L285
# ; │ @ In[20]:29 within `quadroots'
# ; │┌ @ promotion.jl:398 within `=='
# 	testq	%rsi, %rsi
# ; │└
# 	je	L448
# ; │ @ In[20]:36 within `quadroots'
# ; │┌ @ number.jl:118 within `sign'
# ; ││┌ @ operators.jl:294 within `>'
# ; │││┌ @ int.jl:49 within `<'
# 	cmpq	$2, %rsi
# 	movl	$1, %ecx
# ; ││└└
# 	cmovlq	%rsi, %rcx
# ; │└
# ; │┌ @ math.jl:583 within `sqrt'
# ; ││┌ @ float.jl:277 within `float'
# ; │││┌ @ float.jl:262 within `AbstractFloat'
# ; ││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sdq	%rax, %xmm1, %xmm0
# ; │└└└└
# ; │ @ In[20]:37 within `quadroots'
# ; │┌ @ number.jl:118 within `sign'
# 	cmpq	$-2, %rcx
# 	movq	$-1, %rax
# 	cmovgq	%rcx, %rax
# ; │└
# ; │┌ @ int.jl:54 within `*'
# 	addq	%rbx, %rbx
# 	negq	%rbx
# ; │└
# ; │┌ @ promotion.jl:311 within `+'
# ; ││┌ @ promotion.jl:282 within `promote'
# ; │││┌ @ promotion.jl:259 within `_promote'
# ; ││││┌ @ number.jl:7 within `convert'
# ; │││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sdq	%rsi, %xmm1, %xmm1
# ; │└└└└└
# ; │ @ In[20]:36 within `quadroots'
# ; │┌ @ int.jl:51 within `-'
# 	negq	%rsi
# ; │└
# ; │┌ @ promotion.jl:313 within `-'
# ; ││┌ @ promotion.jl:282 within `promote'
# ; │││┌ @ promotion.jl:259 within `_promote'
# ; ││││┌ @ number.jl:7 within `convert'
# ; │││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sdq	%rsi, %xmm2, %xmm2
# ; │└└└└└
# ; │┌ @ math.jl:583 within `sqrt' @ math.jl:558
# 	vsqrtsd	%xmm0, %xmm0, %xmm0
# ; │└
# ; │┌ @ promotion.jl:312 within `*'
# ; ││┌ @ promotion.jl:282 within `promote'
# ; │││┌ @ promotion.jl:259 within `_promote'
# ; ││││┌ @ number.jl:7 within `convert'
# ; │││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sdq	%rax, %xmm3, %xmm3
# ; ││└└└└
# ; ││ @ promotion.jl:312 within `*' @ float.jl:405
# 	vmulsd	%xmm3, %xmm0, %xmm0
# ; │└
# ; │┌ @ promotion.jl:313 within `-' @ float.jl:403
# 	vsubsd	%xmm0, %xmm2, %xmm2
# ; │└
# ; │┌ @ int.jl:54 within `*'
# 	addq	%rdi, %rdi
# ; │└
# ; │┌ @ promotion.jl:314 within `/'
# ; ││┌ @ promotion.jl:282 within `promote'
# ; │││┌ @ promotion.jl:259 within `_promote'
# ; ││││┌ @ number.jl:7 within `convert'
# ; │││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sdq	%rdi, %xmm4, %xmm3
# ; │└└└└└
# ; │ @ In[20]:37 within `quadroots'
# ; │┌ @ promotion.jl:311 within `+' @ float.jl:401
# 	vaddsd	%xmm1, %xmm0, %xmm0
# ; │└
# ; │ @ In[20]:36 within `quadroots'
# ; │┌ @ promotion.jl:314 within `/' @ float.jl:407
# 	vunpcklpd	%xmm0, %xmm3, %xmm0 # xmm0 = xmm3[0],xmm0[0]
# ; │└
# ; │ @ In[20]:37 within `quadroots'
# ; │┌ @ promotion.jl:314 within `/'
# ; ││┌ @ promotion.jl:282 within `promote'
# ; │││┌ @ promotion.jl:259 within `_promote'
# ; ││││┌ @ number.jl:7 within `convert'
# ; │││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sdq	%rbx, %xmm4, %xmm1
# ; │└└└└└
# ; │ @ In[20]:36 within `quadroots'
# ; │┌ @ promotion.jl:314 within `/' @ float.jl:407
# 	vunpcklpd	%xmm1, %xmm2, %xmm1 # xmm1 = xmm2[0],xmm1[0]
# 	vdivpd	%xmm0, %xmm1, %xmm6
# 	movl	$365524560, %edi        # imm = 0x15C97650
# 	jmp	L498
# ; │└
# ; │ @ In[20]:7 within `quadroots'
# ; │┌ @ promotion.jl:398 within `=='
# L245:
# 	testq	%rsi, %rsi
# ; │└
# 	je	L656
# ; │ @ In[20]:14 within `quadroots'
# ; │┌ @ int.jl:51 within `-'
# 	negq	%rbx
# ; │└
# ; │┌ @ int.jl:59 within `/'
# ; ││┌ @ float.jl:277 within `float'
# ; │││┌ @ float.jl:262 within `AbstractFloat'
# ; ││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sdq	%rbx, %xmm1, %xmm0
# 	vcvtsi2sdq	%rsi, %xmm1, %xmm1
# ; ││└└└
# ; ││ @ int.jl:59 within `/' @ float.jl:407
# 	vdivsd	%xmm1, %xmm0, %xmm0
# 	vmovddup	%xmm0, %xmm6    # xmm6 = xmm0[0,0]
# 	movl	$365522416, %edi        # imm = 0x15C96DF0
# ; │└
# ; │ @ In[20]:16 within `quadroots'
# 	jmp	L498
# ; │ @ In[20]:22 within `quadroots'
# ; │┌ @ int.jl:51 within `-'
# L285:
# 	negq	%rax
# ; │└
# ; │┌ @ math.jl:583 within `sqrt'
# ; ││┌ @ float.jl:277 within `float'
# ; │││┌ @ float.jl:262 within `AbstractFloat'
# ; ││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sdq	%rax, %xmm1, %xmm1
# ; ││└└└
# ; ││ @ math.jl:583 within `sqrt' @ math.jl:557
# 	js	L707
# ; │└
# ; │┌ @ int.jl:54 within `*'
# 	addq	%rdi, %rdi
# ; │└
# ; │┌ @ promotion.jl:314 within `/'
# ; ││┌ @ promotion.jl:282 within `promote'
# ; │││┌ @ promotion.jl:259 within `_promote'
# ; ││││┌ @ number.jl:7 within `convert'
# ; │││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sdq	%rdi, %xmm2, %xmm0
# ; │└└└└└
# ; │┌ @ math.jl:583 within `sqrt' @ math.jl:558
# 	vsqrtsd	%xmm1, %xmm1, %xmm1
# ; │└
# ; │┌ @ promotion.jl:314 within `/' @ float.jl:407
# 	vdivsd	%xmm0, %xmm1, %xmm6
# ; │└
# ; │ @ In[20]:23 within `quadroots'
# ; │┌ @ int.jl:51 within `-'
# 	negq	%rsi
# ; │└
# ; │┌ @ int.jl:59 within `/'
# ; ││┌ @ float.jl:277 within `float'
# ; │││┌ @ float.jl:262 within `AbstractFloat'
# ; ││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sdq	%rsi, %xmm2, %xmm1
# ; ││└└└
# ; ││ @ int.jl:59 within `/' @ float.jl:407
# 	vdivsd	%xmm0, %xmm1, %xmm0
# 	movabsq	$524674784, %rax        # imm = 0x1F45E6E0
# 	vmovsd	(%rax), %xmm1           # xmm1 = mem[0],zero
# ; │└
# ; │ @ In[20]:24 within `quadroots'
# ; │┌ @ complex.jl:309 within `*' @ bool.jl:110
# ; ││┌ @ floatfuncs.jl:5 within `copysign'
# 	vandpd	%xmm1, %xmm6, %xmm2
# ; │└└
# ; │┌ @ complex.jl:312 within `+' @ float.jl:401
# 	vaddsd	%xmm2, %xmm0, %xmm7
# ; │└
# ; │ @ In[20]:27 within `quadroots'
# ; │┌ @ complex.jl:263 within `conj'
# ; ││┌ @ float.jl:393 within `-'
# 	vmovddup	%xmm1, %xmm0    # xmm0 = xmm1[0,0]
# 	vxorpd	%xmm0, %xmm6, %xmm8
# ; │└└
# ; │ @ In[20]:42 within `quadroots'
# 	movabsq	$jl_gc_pool_alloc, %rdi
# 	movq	%r14, %rcx
# 	movl	$1424, %edx             # imm = 0x590
# 	movl	$32, %r8d
# 	callq	*%rdi
# 	movq	%rax, %rsi
# 	movq	$169188448, -8(%rsi)    # imm = 0xA159C60
# 	vmovsd	%xmm7, (%rsi)
# 	vmovsd	%xmm6, 8(%rsi)
# 	movq	%rsi, 48(%rsp)
# 	movq	%r14, %rcx
# 	movl	$1424, %edx             # imm = 0x590
# 	movl	$32, %r8d
# 	callq	*%rdi
# 	movq	$169188448, -8(%rax)    # imm = 0xA159C60
# 	vmovsd	%xmm7, (%rax)
# 	vmovlpd	%xmm8, 8(%rax)
# 	movl	$365524560, %edi        # imm = 0x15C97650
# 	jmp	L572
# ; │ @ In[20]:32 within `quadroots'
# ; │┌ @ int.jl:51 within `-'
# L448:
# 	negq	%rbx
# ; │└
# ; │┌ @ math.jl:583 within `sqrt'
# ; ││┌ @ float.jl:277 within `float'
# ; │││┌ @ float.jl:262 within `AbstractFloat'
# ; ││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sdq	%rbx, %xmm1, %xmm1
# ; ││└└└
# ; ││ @ math.jl:583 within `sqrt' @ math.jl:557
# 	js	L728
# ; ││ @ math.jl:583 within `sqrt' @ math.jl:558
# 	vsqrtsd	%xmm1, %xmm1, %xmm0
# ; │└
# ; │┌ @ promotion.jl:314 within `/'
# ; ││┌ @ promotion.jl:282 within `promote'
# ; │││┌ @ promotion.jl:259 within `_promote'
# ; ││││┌ @ number.jl:7 within `convert'
# ; │││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sdq	%rdi, %xmm2, %xmm1
# ; ││└└└└
# ; ││ @ promotion.jl:314 within `/' @ float.jl:407
# 	vdivsd	%xmm1, %xmm0, %xmm0
# 	movabsq	$524674800, %rax        # imm = 0x1F45E6F0
# ; │└
# ; │ @ In[20]:33 within `quadroots'
# ; │┌ @ float.jl:393 within `-'
# 	vxorpd	(%rax), %xmm0, %xmm1
# 	vunpcklpd	%xmm1, %xmm0, %xmm6 # xmm6 = xmm0[0],xmm1[0]
# 	movl	$365524560, %edi        # imm = 0x15C97650
# ; │└
# ; │ @ In[20]:42 within `quadroots'
# L498:
# 	movabsq	$jl_gc_pool_alloc, %rbx
# 	movq	%r14, %rcx
# 	movl	$1400, %edx             # imm = 0x578
# 	movl	$16, %r8d
# 	callq	*%rbx
# 	movq	%rax, %rsi
# 	movq	$169059392, -8(%rsi)    # imm = 0xA13A440
# 	vmovlpd	%xmm6, (%rsi)
# 	movq	%rsi, 48(%rsp)
# 	movq	%r14, %rcx
# 	movl	$1400, %edx             # imm = 0x578
# 	movl	$16, %r8d
# 	callq	*%rbx
# 	movq	$169059392, -8(%rax)    # imm = 0xA13A440
# 	vmovhpd	%xmm6, (%rax)
# L572:
# 	movq	%rsi, 56(%rsp)
# 	movq	%rax, 48(%rsp)
# ; │ @ In[20]:42 within `quadroots'
# 	movq	%rsi, 72(%rsp)
# 	movq	%rax, 80(%rsp)
# 	movq	%rdi, 88(%rsp)
# 	movabsq	$jl_f_tuple, %rax
# 	leaq	72(%rsp), %rdx
# 	xorl	%ecx, %ecx
# 	movl	$3, %r8d
# 	callq	*%rax
# 	movq	40(%rsp), %rcx
# 	movq	%rcx, (%r14)
# 	vmovaps	-80(%rbp), %xmm6
# 	vmovaps	-64(%rbp), %xmm7
# 	vmovaps	-48(%rbp), %xmm8
# 	leaq	-32(%rbp), %rsp
# 	popq	%rbx
# 	popq	%rdi
# 	popq	%rsi
# 	popq	%r14
# 	popq	%rbp
# 	retq
# ; │ @ In[20]:8 within `quadroots'
# ; │┌ @ promotion.jl:398 within `=='
# L656:
# 	testq	%rbx, %rbx
# 	movl	$370462192, %ecx        # imm = 0x1614CDF0
# 	movl	$370462240, %eax        # imm = 0x1614CE20
# ; │└
# 	cmoveq	%rcx, %rax
# 	movq	40(%rsp), %rcx
# 	movq	%rcx, (%r14)
# 	vmovaps	-80(%rbp), %xmm6
# 	vmovaps	-64(%rbp), %xmm7
# 	vmovaps	-48(%rbp), %xmm8
# ; │ @ In[20]:9 within `quadroots'
# 	leaq	-32(%rbp), %rsp
# 	popq	%rbx
# 	popq	%rdi
# 	popq	%rsi
# 	popq	%r14
# 	popq	%rbp
# 	retq
# ; │ @ In[20]:22 within `quadroots'
# ; │┌ @ math.jl:583 within `sqrt' @ math.jl:557
# L707:
# 	movabsq	$throw_complex_domainerror, %rax
# 	movl	$399884432, %ecx        # imm = 0x17D5C090
# 	callq	*%rax
# 	ud2
# 	ud2
# ; │└
# ; │ @ In[20]:32 within `quadroots'
# ; │┌ @ math.jl:583 within `sqrt' @ math.jl:557
# L728:
# 	movabsq	$throw_complex_domainerror, %rax
# 	movl	$399884432, %ecx        # imm = 0x17D5C090
# 	callq	*%rax
# 	ud2
# 	ud2
# 	nopl	(%rax)
# ; └└
