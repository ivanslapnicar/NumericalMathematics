# %% [markdown]
# # Introduction
#
# __Numerical analysis is the science of computing the solutions of problems that are posed
# mathematically in the field of real or complex numbers.__
#
# Let us just give a couple of examples.
#
# ## Computation of $\pi \approx 3.14159265358979$
#
# $\pi$ is known as the ratio of the circumference of a circle and its diameter.
#
# __Archimedes Method__
#
# Inscribe a regular $n$-gon in a circle of radius $1$. Compute the perimeter of its
# upper half. This is easiest to do if $n=2^k$. Using geometric reasoning,
#
# $$
# p(n) = 2n \sin \: \frac{\pi}{2n}.
# $$
#
# Even though this refers to $\pi$ we can compute this value for $n=1,2,\cdots, $ without
# computing $\pi$ and without punching the $\sin$ button on our calculator. (Computing
# the $\sin$ function requires you to know $\pi$!)
#
# From geometric reasoning, we know that
#
# $$
# \sin \: \frac{\pi}{2} =1, \quad \sin \: \frac{\pi}{4} = \frac{\sqrt{2}}{2}.
# $$
#
# So
#
# $$
# p(1)= 2 \cdot \sin \: \frac{\pi}{2} =2, \quad p(2) = 4 \cdot \sin \: \frac{\pi}{4} = 2\sqrt{2}= 2.828427125
# $$
#
# but what is $p(4) = 8 \cdot \sin \: \displaystyle\frac{\pi}{8}$. Use half angle formulas!
#
# \begin{eqnarray*}
# \sin \: \frac{\theta}{2} = \sqrt{\frac{1-\cos \: \theta }{2}}, \quad \cos \: \theta = \sqrt{1-\sin^2 \: \theta } .
# \end{eqnarray*}
#
# That yields
#
# $$
# \sin \: \frac{\pi}{8} = 0.382683432.
# $$
#
# Thus
#
# $$
# p(4) = 8 \cdot \sin \: \frac{\pi}{8}=3.061467459.
# $$
#
# Continuing this process we get
#
# n | $\sin\displaystyle\frac{\pi}{2n}$ | $p(n)$
# :---|:---|:---
# 1 | 1 | 2
# 2 | $\sqrt{0.5}$ | 2.82842712
# 4 |  0.382683432 | 3.061467459
# 8 | 0.195090322 | 3.121445152
# 16 | 0.09801714 | 3.136548491
# 32 | 0.049067674 | 3.140331157
#
# This method is slow, but "sure".

# %%
pi
# Out:
# π = 3.1415926535897...

# %%
steps=20
s=1.0
c=0.0
for n=1:steps
    s=sqrt((1-c)/2)
    c=sqrt(1-s^2)
    println("2n = ", 2^(n+1), ", approximate value of π = ",2^(n+1)*s)
end
"exact π", Float64(pi)
# Out:
# 2n = 4, approximate value of π = 2.8284271247461903
# 2n = 8, approximate value of π = 3.0614674589207187
# 2n = 16, approximate value of π = 3.121445152258053
# 2n = 32, approximate value of π = 3.1365484905459406
# 2n = 64, approximate value of π = 3.140331156954739
# 2n = 128, approximate value of π = 3.141277250932757
# 2n = 256, approximate value of π = 3.1415138011441455
# 2n = 512, approximate value of π = 3.1415729403678827
# 2n = 1024, approximate value of π = 3.141587725279961
# 2n = 2048, approximate value of π = 3.141591421504635
# 2n = 4096, approximate value of π = 3.141592345611077
# 2n = 8192, approximate value of π = 3.1415925765450043
# 2n = 16384, approximate value of π = 3.1415926334632482
# 2n = 32768, approximate value of π = 3.141592654807589
# 2n = 65536, approximate value of π = 3.1415926453212153
# 2n = 131072, approximate value of π = 3.1415926073757197
# 2n = 262144, approximate value of π = 3.1415929109396727
# 2n = 524288, approximate value of π = 3.141594125195191
# 2n = 1048576, approximate value of π = 3.1415965537048196
# 2n = 2097152, approximate value of π = 3.1415965537048196
# ("exact π", 3.141592653589793)

# %% [markdown]
# __Problem.__ Increase the number of steps and explain what happens.

# %% [markdown]
# Later, we will give a modern enhancement that
# is faster. Letting $h=1/(2n)$ we have that
#
# $$
# p(n) = \frac{\sin \: \pi h}{h} = \pi -a_2 h^2 + a_4 h^4 - \cdots
# $$
#
# where $a_k = \pi^{k+1}/(k+1)!$. Thus this converges to $\pi$ at roughly the rate of
# $O(h^2)$. This is an _approximation problem_. There is no finite algorithm
# to compute $\pi$, since it is a transcendental number (irrational and not the root of
# any polynomial with integer coefficients). However, we can approximate it arbitrarily
# well.

# %% [markdown]
# ## Quadratic equation
#
# The following problem poses completely different issues.
#
# Let us compute roots of $p(x) = ax^2 + bx +c =0$ for constants $a$, $b$ and $c$.
#
# The solution is just
#
# $$
# x_{1,2} = \frac{ -b \pm \sqrt{b^2 - 4ac}}{2a}. \tag{1}
# $$
#
# How do we go about writing a code to compute this.
#
# Take care of special cases.
#
# __Case I.__ $a=0, b \neq 0$.
#
# It is no longer a quadratic, it is linear. Only solution is
#
# $$
# x_1 = -c/b.
# $$
#
# __Case II.__ $a=b=0$
#
# If $c \neq 0$, no solution. If $c=0$, all $x$ are solutions.
#
# The cases you spent time on in high school had to do with the discriminant
# $b^2 - 4ac$.
#
# __Case III.__ $b^2 -4ac < 0$. Two Complex Roots (not real).
#
# $$
# x_{1,2} = -\frac{b}{2a} \pm \mathbf{i} \frac{\sqrt{4ac-b^2}}{2a}, \quad \mathbf{i}^2 = -1.
# $$
#
# __Case IV.__ $b^2 - 4ac =0$. One Double Root (real)
#
# $$
# x_1 = x_2 = -\frac{b}{2a}.
# $$
#
# __Case V.__ $b^2 -4ac > 0$. Two Distinct Real Roots.
# Use Formula (1)?

# %%
a=1
b=2
c=10.0^(-17)
x₁=(-b-sqrt(b*b-4*a*c))/(2*a)
x₂=(-b+sqrt(b*b-4*a*c))/(2*a)

x₁,x₂
# Out:
# (-2.0, 0.0)

# %% [markdown]
# The two real roots are (to about 17 digits)
#
# $$
# x_1 = -2, \quad x_2 = -5 \cdot 10^{-18}.
# $$
#
# The above algorithm gets $x_1$ right, but $x_2 = 0$. The standard double precision floating-point number format, `Float64`, stores about $15$ decimal digits (54 binary digits) and in those 15 digits $\sqrt{b^2 -4ac}-b =0$.
# That is because we are subtracting two close numbers and one of these is approximate, so this difference is "all rounding error". A simple observation gets around this problem.
#
# The "large" root of the quadratic in __Case V__ is
#
# $$
# x_1 = \frac{ -b - \mathrm{sign}(b) \sqrt{b^2 - 4ac}}{2a}
# $$
#
# and the two roots satisfy
#
# $$
# x_1 x_2 = \frac{c}{a}.
# $$
#
# Notice that except inside the square root, we are adding numbers of the same sign!
# After some algebra, we get a formula for the small root
#
# $$
# x_2 = \frac{c}{a x_1} = \frac{-2c}{ b + \mathrm{sign}(b) \sqrt{b^2 - 4ac}}.
# $$
#
# Using this formula we compute both roots to near machine precision.
#
# In this example, we have an exact formula, but in floating point arithmetic the standard quadratic formula
# yields results that are significantly different from what it yields in real arithmetic.

# %%
x₁=(-b-sign(b)*sqrt(b*b-4*a*c))/(2*a)
x₂=-2*c/(b+sign(b)*sqrt(b*b-4*a*c))
x₁,x₂
# Out:
# (-2.0, -4.9999999999999996e-18)

# %% [markdown]
# The following function implements all five cases. Try out the function with different inputs and cover all five cases.

# %%
function quadroots(a,b,c)
    # Function to find the roots of the quadratic equation
    # given coefficients a,b, and c.
    # This function takes no account of scaling. 
    if a==0
        #  Check odd cases when a=0 
        if b==0
            if c==0
                return "all numbers are roots a=b=c=0"
            else
                return "no roots a=b=0, c ne 0"
            end
        else
            x₁=-c/b
            x₂=x₁
            ier="one root a=0"
        end
    else
        Δ = b*b-4*a*c
        if Δ < 0
            # Two complex roots computed with real arithmetic
            ximaginary=sqrt(-Δ)/(2*a)
            xreal=-b/(2*a)
            x₁=xreal+im*ximaginary
            # x₂ is the complex conjugate of x₁, 
            # x₂ = xreal - im*ximaginary
            x₂=conj(x₁)
        else
            if b==0
                # Since Julia handles complex arithmetic without a
                # blink, we can just use the formula in this case.
                x₁=sqrt(-c)/a
                x₂=-x₁
            else
                # Case where there are two real roots.
                x₁=(-b-sign(b)*sqrt(Δ))/(2*a)
                x₂=-2*c/(b+sign(b)*sqrt(Δ))
            end
        end
        ier="roots are good"
    end
    x₁, x₂, ier
end
# Out:
# quadroots (generic function with 1 method)

# %%
quadroots(1,0,7)
# Out:
# (0.0 + 2.6457513110645907im, 0.0 - 2.6457513110645907im, "roots are good")

# %%
quadroots(a,b,c)
# Out:
# (-2.0, -4.9999999999999996e-18, "roots are good")

# %% [markdown]
# ## Julia is fast and open
#
# `Julia` is __fast__ and is the first language to solve the "two language problem", for example using Matlab or Python for development and C, C++ or C# for speed. Every function is compiled after the first call using [JIT compiler](https://en.wikipedia.org/wiki/Just-in-time_compilation), in this case [LLVM](https://en.wikipedia.org/wiki/LLVM).
#
# `Julia` is  __open__ since
# * The complete source code is always accessible on GitHub.
# * MIT license.
# * Macro `@which` makes orientation easy.
# * LLVM and assembler codes are easily displayed.

# %%
# Yet another package, follow instructions if not installed.
using Polynomials

# %%
# Contents of a package
varinfo(Polynomials)
# Out:
#   name                       size summary
#   ––––––––––––––––––– ––––––––––– ––––––––––––––––––
#   AbstractPolynomial     40 bytes UnionAll
#   ChebyshevT             40 bytes UnionAll
#   ImmutablePolynomial    80 bytes UnionAll
#   LaurentPolynomial      40 bytes UnionAll
#   Polynomial             40 bytes UnionAll
#   Polynomials         551.221 KiB Module
#   SparsePolynomial       40 bytes UnionAll
#   chop!                   0 bytes typeof(chop!)
#   coeffs                  0 bytes typeof(coeffs)
#   companion               0 bytes typeof(companion)
#   degree                  0 bytes typeof(degree)
#   derivative              0 bytes typeof(derivative)
#   domain                  0 bytes typeof(domain)
#   fit                     0 bytes typeof(fit)
#   fromroots               0 bytes typeof(fromroots)
#   hasnan                  0 bytes typeof(hasnan)
#   integrate               0 bytes typeof(integrate)
#   isintegral              0 bytes typeof(isintegral)
#   ismonic                 0 bytes typeof(ismonic)
#   mapdomain               0 bytes typeof(mapdomain)
#   printpoly               0 bytes typeof(printpoly)
#   roots                   0 bytes typeof(roots)
#   truncate!               0 bytes typeof(truncate!)
#   vander                  0 bytes typeof(vander)
#   variable                0 bytes typeof(variable)

# %%
?Polynomial
# Out:
# search: Polynomial Polynomials LaurentPolynomial AbstractPolynomial
#   Polynomial{T<:Number}(coeffs::AbstractVector{T}, var=:x)
#
#   Construct a polynomial from its coefficients a, lowest order first,
#   optionally in terms of the given variable x. x can be a character, symbol,
#   or string.
#
#   If p = a_n x^n + \ldots + a_2 x^2 + a_1 x + a_0, we construct this through
#   Polynomial([a_0, a_1, ..., a_n]).
#
#   The usual arithmetic operators are overloaded to work with polynomials as
#   well as with combinations of polynomials and scalars. However, operations
#   involving two polynomials of different variables causes an error except
#   those involving a constant polynomial.
#
#   Examples
#   ≡≡≡≡≡≡≡≡≡≡
#
#   DocTestSetup = quote
#       using Polynomials
#   end
#
#   julia> Polynomial([1, 0, 3, 4])
#   Polynomial(1 + 3*x^2 + 4*x^3)
#
#   julia> Polynomial([1, 2, 3], :s)
#   Polynomial(1 + 2*s + 3*s^2)
#
#   julia> one(Polynomial)
#   Polynomial(1.0)

# %%
p=Polynomial([c,b,a])
# Out:
# Polynomial(9.999999999999999e-18 + 2.0*x + 1.0*x^2)

# %%
roots(p)
# Out:
# 2-element Array{Float64,1}:
#  -2.0
#  -4.9999999999999996e-18

# %%
@which roots(p)
# Out:
# roots(p::P; kwargs...) where {T, P<:Polynomials.StandardBasisPolynomial{T}} in Polynomials at C:\Users\Ivan\.julia\packages\Polynomials\r292C\src\polynomials\standard-basis.jl:267

# %% [markdown]
# You can also take a look at the corresponding GitHub file for the most recent version.

# %%
@code_llvm quadroots(1,0,7)
# Out:
# ;  @ In[5]:1 within `quadroots'
# ; Function Attrs: uwtable
# define nonnull %jl_value_t* @julia_quadroots_2331(i64, i64, i64) #0 {
# top:
#   %3 = alloca %jl_value_t*, i32 3
#   %gcframe = alloca %jl_value_t*, i32 4, align 16
#   %4 = bitcast %jl_value_t** %gcframe to i8*
#   call void @llvm.memset.p0i8.i32(i8* align 16 %4, i8 0, i32 32, i1 false)
#   %5 = call %jl_value_t*** inttoptr (i64 1720679280 to %jl_value_t*** ()*)() #8
# ;  @ In[5]:5 within `quadroots'
# ; ┌ @ promotion.jl:398 within `=='
#    %6 = getelementptr %jl_value_t*, %jl_value_t** %gcframe, i32 0
#    %7 = bitcast %jl_value_t** %6 to i64*
#    store i64 8, i64* %7
#    %8 = getelementptr %jl_value_t**, %jl_value_t*** %5, i32 0
#    %9 = getelementptr %jl_value_t*, %jl_value_t** %gcframe, i32 1
#    %10 = bitcast %jl_value_t** %9 to %jl_value_t***
#    %11 = load %jl_value_t**, %jl_value_t*** %8
#    store %jl_value_t** %11, %jl_value_t*** %10
#    %12 = bitcast %jl_value_t*** %8 to %jl_value_t***
#    store %jl_value_t** %gcframe, %jl_value_t*** %12
#    %13 = icmp eq i64 %0, 0
# ; └
#   br i1 %13, label %L3, label %L14
#
# L3:                                               ; preds = %top
# ;  @ In[5]:7 within `quadroots'
# ; ┌ @ promotion.jl:398 within `=='
#    %14 = icmp eq i64 %1, 0
# ; └
#   br i1 %14, label %L5, label %L9
#
# L5:                                               ; preds = %L3
# ;  @ In[5]:8 within `quadroots'
# ; ┌ @ promotion.jl:398 within `=='
#    %15 = icmp eq i64 %2, 0
# ; └
#   %spec.select = select i1 %15, %jl_value_t* inttoptr (i64 343882336 to %jl_value_t*), %jl_value_t* inttoptr (i64 343882384 to %jl_value_t*)
#   %16 = getelementptr %jl_value_t*, %jl_value_t** %gcframe, i32 1
#   %17 = load %jl_value_t*, %jl_value_t** %16
#   %18 = getelementptr %jl_value_t**, %jl_value_t*** %5, i32 0
#   %19 = bitcast %jl_value_t*** %18 to %jl_value_t**
#   store %jl_value_t* %17, %jl_value_t** %19
# ;  @ In[5]:9 within `quadroots'
#   ret %jl_value_t* %spec.select
#
# L9:                                               ; preds = %L3
# ;  @ In[5]:14 within `quadroots'
# ; ┌ @ int.jl:84 within `-'
#    %20 = sub i64 0, %2
# ; └
# ; ┌ @ int.jl:92 within `/'
# ; │┌ @ float.jl:277 within `float'
# ; ││┌ @ float.jl:262 within `AbstractFloat'
# ; │││┌ @ float.jl:60 within `Float64'
#       %21 = sitofp i64 %20 to double
#       %22 = sitofp i64 %1 to double
# ; │└└└
# ; │ @ int.jl:92 within `/' @ float.jl:407
#    %23 = fdiv double %21, %22
#    %24 = bitcast double %23 to i64
#    %25 = insertelement <2 x i64> undef, i64 %24, i32 0
#    %26 = insertelement <2 x i64> %25, i64 %24, i32 1
# ; └
# ;  @ In[5]:16 within `quadroots'
#   br label %box_union7
#
# L14:                                              ; preds = %top
# ;  @ In[5]:19 within `quadroots'
# ; ┌ @ int.jl:87 within `*'
#    %27 = mul i64 %1, %1
# ; └
# ; ┌ @ operators.jl:538 within `*' @ int.jl:87
#    %28 = shl i64 %0, 2
#    %29 = mul i64 %28, %2
# ; └
# ; ┌ @ int.jl:85 within `-'
#    %30 = sub i64 %27, %29
# ; └
# ;  @ In[5]:20 within `quadroots'
# ; ┌ @ int.jl:82 within `<'
#    %31 = icmp sgt i64 %30, -1
# ; └
#   br i1 %31, label %L46, label %L20
#
# L20:                                              ; preds = %L14
# ;  @ In[5]:22 within `quadroots'
# ; ┌ @ int.jl:84 within `-'
#    %32 = sub i64 0, %30
# ; └
# ; ┌ @ math.jl:599 within `sqrt'
# ; │┌ @ float.jl:277 within `float'
# ; ││┌ @ float.jl:262 within `AbstractFloat'
# ; │││┌ @ float.jl:60 within `Float64'
#       %33 = sitofp i64 %32 to double
# ; │└└└
# ; │ @ math.jl:599 within `sqrt' @ math.jl:573
# ; │┌ @ float.jl:458 within `<'
#     %34 = icmp sgt i64 %32, -1
# ; │└
#    br i1 %34, label %box_union6, label %L24
#
# L24:                                              ; preds = %L20
#    %35 = call nonnull %jl_value_t* @j_throw_complex_domainerror_2332(%jl_value_t* inttoptr (i64 406208016 to %jl_value_t*), double %33) #0
#    call void @llvm.trap()
#    unreachable
#
# L46:                                              ; preds = %L14
# ; └
# ;  @ In[5]:29 within `quadroots'
# ; ┌ @ promotion.jl:398 within `=='
#    %36 = icmp eq i64 %1, 0
# ; └
#   br i1 %36, label %L48, label %L71
#
# L48:                                              ; preds = %L46
# ;  @ In[5]:32 within `quadroots'
# ; ┌ @ int.jl:84 within `-'
#    %37 = sub i64 0, %2
# ; └
# ; ┌ @ math.jl:599 within `sqrt'
# ; │┌ @ float.jl:277 within `float'
# ; ││┌ @ float.jl:262 within `AbstractFloat'
# ; │││┌ @ float.jl:60 within `Float64'
#       %38 = sitofp i64 %37 to double
# ; │└└└
# ; │ @ math.jl:599 within `sqrt' @ math.jl:573
# ; │┌ @ float.jl:458 within `<'
#     %39 = icmp sgt i64 %37, -1
# ; │└
#    br i1 %39, label %L54, label %L52
#
# L52:                                              ; preds = %L48
#    %40 = call nonnull %jl_value_t* @j_throw_complex_domainerror_2333(%jl_value_t* inttoptr (i64 406208016 to %jl_value_t*), double %38) #0
#    call void @llvm.trap()
#    unreachable
#
# L54:                                              ; preds = %L48
# ; │ @ math.jl:599 within `sqrt' @ math.jl:574
#    %41 = call double @llvm.sqrt.f64(double %38)
# ; └
# ; ┌ @ promotion.jl:314 within `/'
# ; │┌ @ promotion.jl:282 within `promote'
# ; ││┌ @ promotion.jl:259 within `_promote'
# ; │││┌ @ number.jl:7 within `convert'
# ; ││││┌ @ float.jl:60 within `Float64'
#        %42 = sitofp i64 %0 to double
# ; │└└└└
# ; │ @ promotion.jl:314 within `/' @ float.jl:407
#    %43 = fdiv double %41, %42
# ; └
# ;  @ In[5]:33 within `quadroots'
# ; ┌ @ float.jl:393 within `-'
#    %44 = fsub double -0.000000e+00, %43
#    %45 = insertelement <2 x double> undef, double %43, i32 0
#    %46 = insertelement <2 x double> %45, double %44, i32 1
# ; └
#   br label %union_move19
#
# L71:                                              ; preds = %L46
# ;  @ In[5]:36 within `quadroots'
# ; ┌ @ number.jl:118 within `sign'
# ; │┌ @ operators.jl:303 within `>'
# ; ││┌ @ int.jl:82 within `<'
#      %47 = icmp slt i64 %1, 1
# ; │└└
#    %48 = select i1 %47, i64 %1, i64 1
# ; └
# ; ┌ @ math.jl:599 within `sqrt'
# ; │┌ @ float.jl:277 within `float'
# ; ││┌ @ float.jl:262 within `AbstractFloat'
# ; │││┌ @ float.jl:60 within `Float64'
#       %49 = sitofp i64 %30 to double
# ; └└└└
# ;  @ In[5]:37 within `quadroots'
# ; ┌ @ number.jl:118 within `sign'
#    %50 = icmp sgt i64 %48, -1
#    %51 = select i1 %50, i64 %48, i64 -1
# ; └
# ; ┌ @ int.jl:87 within `*'
#    %52 = mul i64 %2, -2
# ; └
# ;  @ In[5]:36 within `quadroots'
# ; ┌ @ int.jl:84 within `-'
#    %53 = sub i64 0, %1
# ; └
# ; ┌ @ promotion.jl:313 within `-'
# ; │┌ @ promotion.jl:282 within `promote'
# ; ││┌ @ promotion.jl:259 within `_promote'
# ; │││┌ @ number.jl:7 within `convert'
# ; ││││┌ @ float.jl:60 within `Float64'
#        %54 = sitofp i64 %53 to double
# ; └└└└└
# ; ┌ @ math.jl:599 within `sqrt' @ math.jl:574
#    %55 = call double @llvm.sqrt.f64(double %49)
# ; └
# ; ┌ @ promotion.jl:312 within `*'
# ; │┌ @ promotion.jl:282 within `promote'
# ; ││┌ @ promotion.jl:259 within `_promote'
# ; │││┌ @ number.jl:7 within `convert'
# ; ││││┌ @ float.jl:60 within `Float64'
#        %56 = sitofp i64 %51 to double
# ; │└└└└
# ; │ @ promotion.jl:312 within `*' @ float.jl:405
#    %57 = fmul double %55, %56
# ; └
# ; ┌ @ promotion.jl:313 within `-' @ float.jl:403
#    %58 = fsub double %54, %57
# ; └
# ; ┌ @ int.jl:87 within `*'
#    %59 = shl i64 %0, 1
# ; └
# ; ┌ @ promotion.jl:314 within `/'
# ; │┌ @ promotion.jl:282 within `promote'
# ; ││┌ @ promotion.jl:259 within `_promote'
# ; │││┌ @ number.jl:7 within `convert'
# ; ││││┌ @ float.jl:60 within `Float64'
#        %60 = sitofp i64 %59 to double
# ; └└└└└
# ;  @ In[5]:37 within `quadroots'
# ; ┌ @ promotion.jl:311 within `+'
# ; │┌ @ promotion.jl:282 within `promote'
# ; ││┌ @ promotion.jl:259 within `_promote'
# ; │││┌ @ number.jl:7 within `convert'
# ; ││││┌ @ float.jl:60 within `Float64'
#        %61 = sitofp i64 %1 to double
# ; │└└└└
# ; │ @ promotion.jl:311 within `+' @ float.jl:401
#    %62 = fadd double %57, %61
# ; └
# ; ┌ @ promotion.jl:314 within `/'
# ; │┌ @ promotion.jl:282 within `promote'
# ; ││┌ @ promotion.jl:259 within `_promote'
# ; │││┌ @ number.jl:7 within `convert'
# ; ││││┌ @ float.jl:60 within `Float64'
#        %63 = sitofp i64 %52 to double
# ; └└└└└
# ;  @ In[5]:36 within `quadroots'
# ; ┌ @ promotion.jl:314 within `/' @ float.jl:407
#    %64 = insertelement <2 x double> undef, double %58, i32 0
#    %65 = insertelement <2 x double> %64, double %63, i32 1
#    %66 = insertelement <2 x double> undef, double %60, i32 0
#    %67 = insertelement <2 x double> %66, double %62, i32 1
#    %68 = fdiv <2 x double> %65, %67
# ; └
# ;  @ In[5]:37 within `quadroots'
# ; ┌ @ promotion.jl:314 within `/' @ float.jl:407
#    br label %union_move19
#
# post_box_union5:                                  ; preds = %box_union7, %box_union6
#    %69 = phi %jl_value_t* [ %101, %box_union6 ], [ %116, %box_union7 ]
#    %value_phi102121 = phi %jl_value_t* [ inttoptr (i64 344325136 to %jl_value_t*), %box_union6 ], [ %value_phi101, %box_union7 ]
# ; └
# ;  @ In[5]:42 within `quadroots'
#   %70 = phi %jl_value_t* [ %109, %box_union6 ], [ %122, %box_union7 ]
#   %71 = getelementptr %jl_value_t*, %jl_value_t** %gcframe, i32 3
#   store %jl_value_t* %69, %jl_value_t** %71
#   %72 = getelementptr %jl_value_t*, %jl_value_t** %gcframe, i32 2
#   store %jl_value_t* %70, %jl_value_t** %72
#   %73 = getelementptr %jl_value_t*, %jl_value_t** %3, i32 0
#   store %jl_value_t* %69, %jl_value_t** %73
#   %74 = getelementptr %jl_value_t*, %jl_value_t** %3, i32 1
#   store %jl_value_t* %70, %jl_value_t** %74
#   %75 = getelementptr %jl_value_t*, %jl_value_t** %3, i32 2
#   store %jl_value_t* %value_phi102121, %jl_value_t** %75
#   %76 = call nonnull %jl_value_t* @jl_f_tuple(%jl_value_t* null, %jl_value_t** %3, i32 3)
#   %77 = getelementptr %jl_value_t*, %jl_value_t** %gcframe, i32 1
#   %78 = load %jl_value_t*, %jl_value_t** %77
#   %79 = getelementptr %jl_value_t**, %jl_value_t*** %5, i32 0
#   %80 = bitcast %jl_value_t*** %79 to %jl_value_t**
#   store %jl_value_t* %78, %jl_value_t** %80
#   ret %jl_value_t* %76
#
# box_union6:                                       ; preds = %L20
# ;  @ In[5]:22 within `quadroots'
# ; ┌ @ math.jl:599 within `sqrt' @ math.jl:574
#    %81 = call double @llvm.sqrt.f64(double %33)
# ; └
# ; ┌ @ int.jl:87 within `*'
#    %82 = shl i64 %0, 1
# ; └
# ; ┌ @ promotion.jl:314 within `/'
# ; │┌ @ promotion.jl:282 within `promote'
# ; ││┌ @ promotion.jl:259 within `_promote'
# ; │││┌ @ number.jl:7 within `convert'
# ; ││││┌ @ float.jl:60 within `Float64'
#        %83 = sitofp i64 %82 to double
# ; └└└└└
# ;  @ In[5]:23 within `quadroots'
# ; ┌ @ int.jl:84 within `-'
#    %84 = sub i64 0, %1
# ; └
# ; ┌ @ int.jl:92 within `/'
# ; │┌ @ float.jl:277 within `float'
# ; ││┌ @ float.jl:262 within `AbstractFloat'
# ; │││┌ @ float.jl:60 within `Float64'
#       %85 = sitofp i64 %84 to double
# ; │└└└
# ; │ @ int.jl:92 within `/' @ float.jl:407
#    %86 = insertelement <2 x double> undef, double %85, i32 0
#    %87 = insertelement <2 x double> %86, double %81, i32 1
#    %88 = insertelement <2 x double> undef, double %83, i32 0
#    %89 = insertelement <2 x double> %88, double %83, i32 1
#    %90 = fdiv <2 x double> %87, %89
# ; └
# ;  @ In[5]:24 within `quadroots'
# ; ┌ @ complex.jl:309 within `*' @ bool.jl:110
# ; │┌ @ floatfuncs.jl:5 within `copysign'
#     %91 = extractelement <2 x double> %90, i32 1
#     %92 = bitcast double %91 to i64
#     %93 = and i64 %92, -9223372036854775808
# ; │└
#    %94 = bitcast i64 %93 to double
# ; └
# ; ┌ @ complex.jl:312 within `+' @ float.jl:401
#    %95 = insertelement <2 x double> undef, double %94, i32 0
#    %96 = insertelement <2 x double> %95, double -0.000000e+00, i32 1
#    %97 = fadd <2 x double> %96, %90
#    %98 = fsub <2 x double> %96, %90
#    %99 = shufflevector <2 x double> %97, <2 x double> %98, <2 x i32> <i32 0, i32 3>
# ; └
# ;  @ In[5]:42 within `quadroots'
#   %100 = bitcast %jl_value_t*** %5 to i8*
#   %101 = call noalias nonnull %jl_value_t* @jl_gc_pool_alloc(i8* %100, i32 1424, i32 32) #3
#   %102 = bitcast %jl_value_t* %101 to %jl_value_t**
#   %103 = getelementptr %jl_value_t*, %jl_value_t** %102, i64 -1
#   store %jl_value_t* inttoptr (i64 176548688 to %jl_value_t*), %jl_value_t** %103
#   %104 = bitcast %jl_value_t* %101 to i8*
#   %105 = bitcast %jl_value_t* %101 to double*
#   %106 = extractelement <2 x double> %99, i32 0
#   store double %106, double* %105, align 8
#   %.sroa.376.0..sroa_idx = getelementptr inbounds i8, i8* %104, i64 8
#   %107 = bitcast i8* %.sroa.376.0..sroa_idx to double*
#   store double %91, double* %107, align 8
#   %108 = getelementptr %jl_value_t*, %jl_value_t** %gcframe, i32 2
#   store %jl_value_t* %101, %jl_value_t** %108
#   %109 = call noalias nonnull %jl_value_t* @jl_gc_pool_alloc(i8* %100, i32 1424, i32 32) #3
#   %110 = bitcast %jl_value_t* %109 to %jl_value_t**
#   %111 = getelementptr %jl_value_t*, %jl_value_t** %110, i64 -1
#   store %jl_value_t* inttoptr (i64 176548688 to %jl_value_t*), %jl_value_t** %111
#   %112 = bitcast %jl_value_t* %109 to double*
#   %113 = bitcast double* %112 to <2 x double>*
#   store <2 x double> %99, <2 x double>* %113, align 8
#   br label %post_box_union5
#
# box_union7:                                       ; preds = %union_move19, %L9
#   %value_phi101 = phi %jl_value_t* [ inttoptr (i64 344322800 to %jl_value_t*), %L9 ], [ inttoptr (i64 344325136 to %jl_value_t*), %union_move19 ]
#   %114 = phi <2 x i64> [ %26, %L9 ], [ %128, %union_move19 ]
#   %115 = bitcast %jl_value_t*** %5 to i8*
#   %116 = call noalias nonnull %jl_value_t* @jl_gc_pool_alloc(i8* %115, i32 1400, i32 16) #3
#   %117 = bitcast %jl_value_t* %116 to %jl_value_t**
#   %118 = getelementptr %jl_value_t*, %jl_value_t** %117, i64 -1
#   store %jl_value_t* inttoptr (i64 176346160 to %jl_value_t*), %jl_value_t** %118
#   %119 = bitcast %jl_value_t* %116 to i64*
#   %120 = extractelement <2 x i64> %114, i32 0
#   store i64 %120, i64* %119, align 8
#   %121 = getelementptr %jl_value_t*, %jl_value_t** %gcframe, i32 2
#   store %jl_value_t* %116, %jl_value_t** %121
#   %122 = call noalias nonnull %jl_value_t* @jl_gc_pool_alloc(i8* %115, i32 1400, i32 16) #3
#   %123 = bitcast %jl_value_t* %122 to %jl_value_t**
#   %124 = getelementptr %jl_value_t*, %jl_value_t** %123, i64 -1
#   store %jl_value_t* inttoptr (i64 176346160 to %jl_value_t*), %jl_value_t** %124
#   %125 = bitcast %jl_value_t* %122 to i64*
#   %126 = extractelement <2 x i64> %114, i32 1
#   store i64 %126, i64* %125, align 8
#   br label %post_box_union5
#
# union_move19:                                     ; preds = %L71, %L54
#   %127 = phi <2 x double> [ %46, %L54 ], [ %68, %L71 ]
# ;  @ In[5]:40 within `quadroots'
#   %128 = bitcast <2 x double> %127 to <2 x i64>
#   br label %box_union7
# }

# %%
@code_native quadroots(1,0,7)
# Out:
# 	.text
# ; ┌ @ In[5]:1 within `quadroots'
# 	pushq	%rbp
# 	movq	%rsp, %rbp
# 	pushq	%r14
# 	pushq	%rsi
# 	pushq	%rdi
# 	pushq	%rbx
# 	andq	$-32, %rsp
# 	subq	$160, %rsp
# 	vmovapd	%xmm8, -48(%rbp)
# 	vmovapd	%xmm7, -64(%rbp)
# 	vmovaps	%xmm6, -80(%rbp)
# 	movq	%r8, %rbx
# 	movq	%rdx, %rsi
# 	movq	%rcx, %rdi
# 	vxorpd	%xmm0, %xmm0, %xmm0
# 	vmovapd	%ymm0, 32(%rsp)
# 	movl	$jl_get_ptls_states, %eax
# 	vzeroupper
# 	callq	*%rax
# 	movq	%rax, %r14
# ; │ @ In[5]:5 within `quadroots'
# ; │┌ @ promotion.jl:398 within `=='
# 	movq	$8, 32(%rsp)
# 	movq	(%r14), %rax
# 	movq	%rax, 40(%rsp)
# 	leaq	32(%rsp), %rax
# 	movq	%rax, (%r14)
# 	testq	%rdi, %rdi
# ; │└
# 	je	L240
# ; │ @ In[5]:19 within `quadroots'
# ; │┌ @ int.jl:87 within `*'
# 	movq	%rsi, %rax
# 	imulq	%rax, %rax
# ; │└
# ; │┌ @ operators.jl:538 within `*' @ int.jl:87
# 	movq	%rdi, %rcx
# 	imulq	%rbx, %rcx
# 	shlq	$2, %rcx
# ; │└
# ; │ @ In[5]:20 within `quadroots'
# ; │┌ @ int.jl:82 within `<'
# 	subq	%rcx, %rax
# ; │└
# 	js	L280
# ; │ @ In[5]:29 within `quadroots'
# ; │┌ @ promotion.jl:398 within `=='
# 	testq	%rsi, %rsi
# ; │└
# 	je	L465
# ; │ @ In[5]:36 within `quadroots'
# ; │┌ @ number.jl:118 within `sign'
# ; ││┌ @ operators.jl:303 within `>'
# ; │││┌ @ int.jl:82 within `<'
# 	cmpq	$2, %rsi
# 	movl	$1, %ecx
# ; ││└└
# 	cmovlq	%rsi, %rcx
# ; │└
# ; │┌ @ math.jl:599 within `sqrt'
# ; ││┌ @ float.jl:277 within `float'
# ; │││┌ @ float.jl:262 within `AbstractFloat'
# ; ││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sd	%rax, %xmm1, %xmm0
# ; │└└└└
# ; │ @ In[5]:37 within `quadroots'
# ; │┌ @ number.jl:118 within `sign'
# 	cmpq	$-2, %rcx
# 	movq	$-1, %rax
# 	cmovgq	%rcx, %rax
# ; │└
# ; │┌ @ int.jl:87 within `*'
# 	addq	%rbx, %rbx
# ; │└
# ; │┌ @ promotion.jl:311 within `+'
# ; ││┌ @ promotion.jl:282 within `promote'
# ; │││┌ @ promotion.jl:259 within `_promote'
# ; ││││┌ @ number.jl:7 within `convert'
# ; │││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sd	%rsi, %xmm1, %xmm1
# ; │└└└└└
# ; │┌ @ int.jl:87 within `*'
# 	negq	%rbx
# ; │└
# ; │ @ In[5]:36 within `quadroots'
# ; │┌ @ int.jl:84 within `-'
# 	negq	%rsi
# ; │└
# ; │┌ @ promotion.jl:313 within `-'
# ; ││┌ @ promotion.jl:282 within `promote'
# ; │││┌ @ promotion.jl:259 within `_promote'
# ; ││││┌ @ number.jl:7 within `convert'
# ; │││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sd	%rsi, %xmm2, %xmm2
# ; │└└└└└
# ; │┌ @ promotion.jl:312 within `*'
# ; ││┌ @ promotion.jl:282 within `promote'
# ; │││┌ @ promotion.jl:259 within `_promote'
# ; ││││┌ @ number.jl:7 within `convert'
# ; │││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sd	%rax, %xmm3, %xmm3
# ; │└└└└└
# ; │┌ @ math.jl:599 within `sqrt' @ math.jl:574
# 	vsqrtsd	%xmm0, %xmm0, %xmm0
# ; │└
# ; │┌ @ promotion.jl:312 within `*' @ float.jl:405
# 	vmulsd	%xmm3, %xmm0, %xmm0
# ; │└
# ; │┌ @ promotion.jl:313 within `-' @ float.jl:403
# 	vsubsd	%xmm0, %xmm2, %xmm2
# ; │└
# ; │┌ @ int.jl:87 within `*'
# 	addq	%rdi, %rdi
# ; │└
# ; │┌ @ promotion.jl:314 within `/'
# ; ││┌ @ promotion.jl:282 within `promote'
# ; │││┌ @ promotion.jl:259 within `_promote'
# ; ││││┌ @ number.jl:7 within `convert'
# ; │││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sd	%rdi, %xmm4, %xmm3
# ; │└└└└└
# ; │ @ In[5]:37 within `quadroots'
# ; │┌ @ promotion.jl:311 within `+' @ float.jl:401
# 	vaddsd	%xmm1, %xmm0, %xmm0
# ; │└
# ; │ @ In[5]:36 within `quadroots'
# ; │┌ @ promotion.jl:314 within `/' @ float.jl:407
# 	vunpcklpd	%xmm0, %xmm3, %xmm0 # xmm0 = xmm3[0],xmm0[0]
# ; │└
# ; │ @ In[5]:37 within `quadroots'
# ; │┌ @ promotion.jl:314 within `/'
# ; ││┌ @ promotion.jl:282 within `promote'
# ; │││┌ @ promotion.jl:259 within `_promote'
# ; ││││┌ @ number.jl:7 within `convert'
# ; │││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sd	%rbx, %xmm4, %xmm1
# ; │└└└└└
# ; │ @ In[5]:36 within `quadroots'
# ; │┌ @ promotion.jl:314 within `/' @ float.jl:407
# 	vunpcklpd	%xmm1, %xmm2, %xmm1 # xmm1 = xmm2[0],xmm1[0]
# 	vdivpd	%xmm0, %xmm1, %xmm6
# 	jmp	L510
# ; │└
# ; │ @ In[5]:7 within `quadroots'
# ; │┌ @ promotion.jl:398 within `=='
# L240:
# 	testq	%rsi, %rsi
# ; │└
# 	je	L675
# ; │ @ In[5]:14 within `quadroots'
# ; │┌ @ int.jl:84 within `-'
# 	negq	%rbx
# ; │└
# ; │┌ @ int.jl:92 within `/'
# ; ││┌ @ float.jl:277 within `float'
# ; │││┌ @ float.jl:262 within `AbstractFloat'
# ; ││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sd	%rbx, %xmm1, %xmm0
# 	vcvtsi2sd	%rsi, %xmm1, %xmm1
# ; ││└└└
# ; ││ @ int.jl:92 within `/' @ float.jl:407
# 	vdivsd	%xmm1, %xmm0, %xmm0
# 	vmovddup	%xmm0, %xmm6    # xmm6 = xmm0[0,0]
# 	movl	$344322800, %edi        # imm = 0x1485F2F0
# ; │└
# ; │ @ In[5]:16 within `quadroots'
# 	jmp	L515
# ; │ @ In[5]:22 within `quadroots'
# ; │┌ @ int.jl:84 within `-'
# L280:
# 	negq	%rax
# ; │└
# ; │┌ @ math.jl:599 within `sqrt'
# ; ││┌ @ float.jl:277 within `float'
# ; │││┌ @ float.jl:262 within `AbstractFloat'
# ; ││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sd	%rax, %xmm1, %xmm1
# ; ││└└└
# ; ││ @ math.jl:599 within `sqrt' @ math.jl:573
# 	js	L726
# ; ││ @ math.jl:599 within `sqrt' @ math.jl:574
# 	vsqrtsd	%xmm1, %xmm1, %xmm0
# ; │└
# ; │┌ @ int.jl:87 within `*'
# 	addq	%rdi, %rdi
# ; │└
# ; │┌ @ promotion.jl:314 within `/'
# ; ││┌ @ promotion.jl:282 within `promote'
# ; │││┌ @ promotion.jl:259 within `_promote'
# ; ││││┌ @ number.jl:7 within `convert'
# ; │││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sd	%rdi, %xmm2, %xmm1
# ; │└└└└└
# ; │ @ In[5]:23 within `quadroots'
# ; │┌ @ int.jl:84 within `-'
# 	negq	%rsi
# ; │└
# ; │┌ @ int.jl:92 within `/'
# ; ││┌ @ float.jl:277 within `float'
# ; │││┌ @ float.jl:262 within `AbstractFloat'
# ; ││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sd	%rsi, %xmm2, %xmm2
# ; ││└└└
# ; ││ @ int.jl:92 within `/' @ float.jl:407
# 	vunpcklpd	%xmm0, %xmm2, %xmm0 # xmm0 = xmm2[0],xmm0[0]
# 	vmovddup	%xmm1, %xmm1    # xmm1 = xmm1[0,0]
# 	vdivpd	%xmm1, %xmm0, %xmm6
# ; │└
# ; │ @ In[5]:24 within `quadroots'
# ; │┌ @ complex.jl:309 within `*' @ bool.jl:110
# ; ││┌ @ floatfuncs.jl:5 within `copysign'
# 	vpermilpd	$1, %xmm6, %xmm0 # xmm0 = xmm6[1,0]
# 	movabsq	$.rodata.cst8, %rax
# 	vmovsd	(%rax), %xmm1           # xmm1 = mem[0],zero
# 	vandpd	%xmm1, %xmm0, %xmm0
# 	movabsq	$.rodata.cst16, %rax
# ; │└└
# ; │┌ @ complex.jl:312 within `+' @ float.jl:401
# 	vblendpd	$2, (%rax), %xmm0, %xmm7 # xmm7 = xmm0[0],mem[1]
# 	vaddpd	%xmm6, %xmm7, %xmm0
# 	vsubpd	%xmm6, %xmm7, %xmm1
# 	vblendpd	$1, %xmm0, %xmm1, %xmm8 # xmm8 = xmm0[0],xmm1[1]
# ; │└
# ; │ @ In[5]:42 within `quadroots'
# 	movabsq	$jl_gc_pool_alloc, %rdi
# 	movq	%r14, %rcx
# 	movl	$1424, %edx             # imm = 0x590
# 	movl	$32, %r8d
# 	callq	*%rdi
# 	movq	%rax, %rsi
# 	movq	$176548688, -8(%rsi)    # imm = 0xA85EB50
# 	vaddsd	%xmm7, %xmm6, %xmm0
# 	vmovupd	%xmm0, (%rsi)
# 	movq	%rsi, 48(%rsp)
# 	movq	%r14, %rcx
# 	movl	$1424, %edx             # imm = 0x590
# 	movl	$32, %r8d
# 	callq	*%rdi
# 	movq	$176548688, -8(%rax)    # imm = 0xA85EB50
# 	vmovupd	%xmm8, (%rax)
# 	movl	$344325136, %edi        # imm = 0x1485FC10
# 	jmp	L591
# ; │ @ In[5]:32 within `quadroots'
# ; │┌ @ int.jl:84 within `-'
# L465:
# 	negq	%rbx
# ; │└
# ; │┌ @ math.jl:599 within `sqrt'
# ; ││┌ @ float.jl:277 within `float'
# ; │││┌ @ float.jl:262 within `AbstractFloat'
# ; ││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sd	%rbx, %xmm1, %xmm1
# ; ││└└└
# ; ││ @ math.jl:599 within `sqrt' @ math.jl:573
# 	js	L747
# ; │└
# ; │┌ @ promotion.jl:314 within `/'
# ; ││┌ @ promotion.jl:282 within `promote'
# ; │││┌ @ promotion.jl:259 within `_promote'
# ; ││││┌ @ number.jl:7 within `convert'
# ; │││││┌ @ float.jl:60 within `Float64'
# 	vcvtsi2sd	%rdi, %xmm2, %xmm0
# ; │└└└└└
# ; │┌ @ math.jl:599 within `sqrt' @ math.jl:574
# 	vsqrtsd	%xmm1, %xmm1, %xmm1
# ; │└
# ; │┌ @ promotion.jl:314 within `/' @ float.jl:407
# 	vdivsd	%xmm0, %xmm1, %xmm0
# 	movabsq	$530830496, %rax        # imm = 0x1FA3D4A0
# ; │└
# ; │ @ In[5]:33 within `quadroots'
# ; │┌ @ float.jl:393 within `-'
# 	vxorpd	(%rax), %xmm0, %xmm1
# 	vunpcklpd	%xmm1, %xmm0, %xmm6 # xmm6 = xmm0[0],xmm1[0]
# ; └└
# ; ┌ @ float.jl within `quadroots'
# L510:
# 	movl	$344325136, %edi        # imm = 0x1485FC10
# ; └
# ; ┌ @ In[5]:42 within `quadroots'
# L515:
# 	movabsq	$jl_gc_pool_alloc, %rbx
# 	movq	%r14, %rcx
# 	movl	$1400, %edx             # imm = 0x578
# 	movl	$16, %r8d
# 	callq	*%rbx
# 	movq	%rax, %rsi
# 	movq	$176346160, -8(%rsi)    # imm = 0xA82D430
# 	vmovlpd	%xmm6, (%rsi)
# 	movq	%rsi, 48(%rsp)
# 	movq	%r14, %rcx
# 	movl	$1400, %edx             # imm = 0x578
# 	movl	$16, %r8d
# 	callq	*%rbx
# 	movq	$176346160, -8(%rax)    # imm = 0xA82D430
# 	vpextrq	$1, %xmm6, (%rax)
# L591:
# 	movq	%rsi, 56(%rsp)
# 	movq	%rax, 48(%rsp)
# ; │ @ In[5]:42 within `quadroots'
# 	movq	%rsi, 72(%rsp)
# 	movq	%rax, 80(%rsp)
# 	movq	%rdi, 88(%rsp)
# 	movabsq	$jl_f_tuple, %rax
# 	leaq	72(%rsp), %rdx
# 	xorl	%ecx, %ecx
# 	movl	$3, %r8d
# 	callq	*%rax
# 	movq	40(%rsp), %rcx
# 	movq	%rcx, (%r14)
# 	vmovaps	-80(%rbp), %xmm6
# 	vmovaps	-64(%rbp), %xmm7
# 	vmovaps	-48(%rbp), %xmm8
# 	leaq	-32(%rbp), %rsp
# 	popq	%rbx
# 	popq	%rdi
# 	popq	%rsi
# 	popq	%r14
# 	popq	%rbp
# 	retq
# ; │ @ In[5]:8 within `quadroots'
# ; │┌ @ promotion.jl:398 within `=='
# L675:
# 	testq	%rbx, %rbx
# 	movl	$343882336, %ecx        # imm = 0x147F3A60
# 	movl	$343882384, %eax        # imm = 0x147F3A90
# ; │└
# 	cmoveq	%rcx, %rax
# 	movq	40(%rsp), %rcx
# 	movq	%rcx, (%r14)
# 	vmovaps	-80(%rbp), %xmm6
# 	vmovaps	-64(%rbp), %xmm7
# 	vmovaps	-48(%rbp), %xmm8
# ; │ @ In[5]:9 within `quadroots'
# 	leaq	-32(%rbp), %rsp
# 	popq	%rbx
# 	popq	%rdi
# 	popq	%rsi
# 	popq	%r14
# 	popq	%rbp
# 	retq
# ; │ @ In[5]:22 within `quadroots'
# ; │┌ @ math.jl:599 within `sqrt' @ math.jl:573
# L726:
# 	movabsq	$throw_complex_domainerror, %rax
# 	movl	$406208016, %ecx        # imm = 0x18363E10
# 	callq	*%rax
# 	ud2
# 	ud2
# ; │└
# ; │ @ In[5]:32 within `quadroots'
# ; │┌ @ math.jl:599 within `sqrt' @ math.jl:573
# L747:
# 	movabsq	$throw_complex_domainerror, %rax
# 	movl	$406208016, %ecx        # imm = 0x18363E10
# 	callq	*%rax
# 	ud2
# 	ud2
# ; └└
